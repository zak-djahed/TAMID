# %%
import pandas as pd

# Replace this with the path to ONE of your actual pkl files
path = "/Users/zakdjahed/Desktop/TAMID/Projects/2025-2026/OPPRCD_SPX/pickles/with_spx/with_iv_greeks/SPX_OPTIONS_01011996.pkl"

df = pd.read_pickle(path)

print("Columns in file:")
print(df.columns.tolist())

print("\nFirst 5 rows:")
print(df.head())

print("\nData types:")
print(df.dtypes)
# Out:
# Columns in file:
# ['SecurityID', 'Date', 'symbol', 'symbolflag', 'Strike', 'Expiration', 'CallPut', 'BestBid', 'BestOffer', 'LastTradeDate', 'Volume', 'OpenInterest', 'SpecialSettlement', 'OptionID2', 'AdjustmentFactor', 'AMSettlement', 'ContractSize', 'ExpiryIndicator', 'SPX_AdjClose', 'ImpliedVolatility', 'Delta', 'Gamma', 'Theta', 'Theta_per_day', 'Vega']
#
# First 5 rows:
#             SecurityID      Date    symbol  symbolflag  Strike  Expiration  \
# Date
# 1996-01-04      108105  19960104  098A3.1A           0  600000    19960316
# 1996-01-05      108105  19960105  098A3.1A           0  600000    19960316
# 1996-01-08      108105  19960108  098A3.1A           0  600000    19960316
# 1996-01-09      108105  19960109  098A3.1A           0  600000    19960316
# 1996-01-10      108105  19960110  098A3.1A           0  600000    19960316
#
#            CallPut  BestBid  BestOffer  LastTradeDate  ...  AMSettlement  \
# Date                                                   ...
# ...
